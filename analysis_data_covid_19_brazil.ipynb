# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielaSVanzelli/Data-Science/blob/main/analysis_data_covid_19_brazil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Overview of COVID-19 in Brazil**
#
# COVID-19 is an infectious disease caused by the newly discovered coronavirus.
#
# Transmitted primarily through droplets from the coughs or sneezes of infected people, the severity of symptoms varies greatly from person to person.
#
# Because it is a newly discovered virus, not much is known about the disease, symptoms and possible sequelae. Studies are being carried out all over the world, but the results are still not conclusive and definitive. There is always new information being discovered.
#
# <center><img alt="COVID-10 projeto" width="50%" src="https://raw.githubusercontent.com/rafaelgrecco/Imagens-datasets/master/4198555.jpg"></center>
#
# Currently, it is observed that about 80% of confirmed cases are asymptomatic and rapid. Most people who fall into this group recover without any sequelae.
#
# However, 15% of people will have serious infections and will need oxygen. The rest of the people, representing 5%, will be classified as very serious infections and will need assisted ventilation, through mechanical respirators in a hospital environment.
#
# The most affected group are the elderly and people with some type of comorbidity, mainly comorbidities related to respiratory problems. These people are most at risk of developing severe symptoms when contracting the disease or even dying.
#
# In order to raise situational awareness about COVID-19 in Brazil, I will carry out an analysis of public data on the disease.

# %% [markdown]
# ## **Obtaining the Data**
#
#   All data used in this analysis were taken from the [Our World in Data](https://ourworldindata.org/coronavirus) website, more specifically from the COVID-19 data collection.
#
# <center><img alt="Our World in Data" width="10%" src="https://raw.githubusercontent.com/GabrielaSVanzelli/images/main/Our%20World%20in%20Data.jpg"></center>
#
#   Every data analysis has its difficulties, but analyzing data about a new disease has other challenges. One of them is the lack of consolidated data, which means that for a new disease, information is constantly changing, there was not enough time to carry out some studies and there is always new information that changes the whole scenario.
#
#   Since the beginning of the pandemic, until the present moment (2022/04/29) a lot of new information has emerged and others have been demystified, in this way, judging which information is really relevant or reliable to build a data analysis is a great challenge.

# %% [markdown]
# ### **Dictionary of dataset variables**
#
# **Confirmed cases**
#
# *   `total_cases` - Total confirmed cases of COVID-19. Counts can include probable cases, where reported.
#
# *   `new_cases` - New confirmed cases of COVID-19. Counts can include probable cases, where reported. In rare cases where our source reports a negative daily change due to a data correction, we set this metric to NA.
#
# *   `new_cases_smoothed` - New confirmed cases of COVID-19 (7-day smoothed). Counts can include probable cases, where reported.
#
# *   `total_cases_per_million` - Total confirmed cases of COVID-19 per 1,000,000 people. Counts can include probable cases, where reported.
#
# *   `new_cases_per_million` - New confirmed cases of COVID-19 per 1,000,000 people. Counts can include probable cases, where reported.
#
# *   `new_cases_smoothed_per_million` - New confirmed cases of COVID-19 (7-day smoothed) per 1,000,000 people. Counts can include probable cases, where reported.

# %% [markdown]
# **Confirmed deaths**
#
# *   `total_deaths` - Total deaths attributed to COVID-19. Counts can include probable deaths, where reported.
#
# *   `new_deaths` - New deaths attributed to COVID-19. Counts can include probable deaths, where reported. In rare cases where our source reports a negative daily change due to a data correction, we set this metric to NA.
#
# *   `new_deaths_smoothed` - New deaths attributed to COVID-19 (7-day smoothed). Counts can include probable deaths, where reported.
#
# *   `total_deaths_per_million` - Total deaths attributed to COVID-19 per 1,000,000 people. Counts can include probable deaths, where reported.
#
# *   `new_deaths_per_million` - New deaths attributed to COVID-19 per 1,000,000 people. Counts can include probable deaths, where reported.
#
# *   `new_deaths_smoothed_per_million` - New deaths attributed to COVID-19 (7-day smoothed) per 1,000,000 people. Counts can include probable deaths, where reported.

# %% [markdown]
# **Excess mortality**
#
#
#
# *   `excess_mortality` - Percentage difference between the reported number of weekly or monthly deaths in 2020–2021 and the projected number of deaths for the same period based on previous years.
#
# *   `excess_mortality_cumulative` - Percentage difference between the cumulative number of deaths since 1 January 2020 and the cumulative projected deaths for the same period based on previous years.
#
# *   `excess_mortality_cumulative_absolute` - Cumulative difference between the reported number of deaths since 1 January 2020 and the projected number of deaths for the same period based on previous years.
#
# *   `excess_mortality_cumulative_per_million` - Cumulative difference between the reported number of deaths since 1 January 2020 and the projected number of deaths for the same period based on previous years, per million people.

# %% [markdown]
# **Hospital & ICU**
#
#
#
# *   `icu_patients` - Number of COVID-19 patients in intensive care units (ICUs) on a given day
#
# *   `icu_patients_per_million` - Number of COVID-19 patients in intensive care units (ICUs) on a given day per 1,000,000 people
#
# *   `hosp_patients` - Number of COVID-19 patients in hospital on a given day
#
# *   `hosp_patients_per_million` - Number of COVID-19 patients in hospital on a given day per 1,000,000 people
#
# *   `weekly_icu_admissions` - Number of COVID-19 patients newly admitted to intensive care units (ICUs) in a given week
#
# *   `weekly_icu_admissions_per_million` - Number of COVID-19 patients newly admitted to intensive care units (ICUs) in a given week per 1,000,000 people
#
# *   `weekly_hosp_admissions` - Number of COVID-19 patients newly admitted to hospitals in a given week
#
# *   `weekly_hosp_admissions_per_million` - Number of COVID-19 patients newly admitted to hospitals in a given week per 1,000,000 people

# %% [markdown]
# **Policy responses**
#
# *   `stringency_index` - Government Response Stringency Index: composite measure based on 9 response indicators including school closures, workplace closures, and travel bans, rescaled to a value from 0 to 100 (100 = strictest response)

# %% [markdown]
# **Reproduction rate**
#
# * `reproduction_rate` - Real-time estimate of the effective reproduction rate (R) of COVID-19.

# %% [markdown]
# **Tests & positivity**
#
# *   `total_tests` - Total tests for COVID-19
#
# *   `new_tests` - New tests for COVID-19 (only calculated for consecutive days)
#
# *   `total_tests_per_thousand` - Total tests for COVID-19 per 1,000 people
#
# *   `new_tests_per_thousand` - New tests for COVID-19 per 1,000 people
#
# *   `new_tests_smoothed` - New tests for COVID-19 (7-day smoothed). For countries that don't report testing data on a daily basis, we assume that testing changed equally on a daily basis over any periods in which no data was reported. This produces a complete series of daily figures, which is then averaged over a rolling 7-day window
#
# *   `new_tests_smoothed_per_thousand` - New tests for COVID-19 (7-day smoothed) per 1,000 people
#
# *   `positive_rate` - The share of COVID-19 tests that are positive, given as a rolling 7-day average (this is the inverse of tests_per_case)
#
# *   `tests_per_case` - Tests conducted per new confirmed case of COVID-19, given as a rolling 7-day average (this is the inverse of positive_rate)
#
# *   `tests_units` - Units used by the location to report its testing data

# %% [markdown]
# **Vaccinations**
#
#
# *   `total_vaccinations` - Total number of COVID-19 vaccination doses administered
#
# *   `people_vaccinated` - Total number of people who received at least one vaccine dose
#
# *   `people_fully_vaccinated` - Total number of people who received all doses prescribed by the initial vaccination protocol
#
# *   `total_boosters` - Total number of COVID-19 vaccination booster doses administered (doses administered beyond the number prescribed by the vaccination protocol)
#
# *   `new_vaccinations` - New COVID-19 vaccination doses administered (only calculated for consecutive days)
#
# *   `new_vaccinations_smoothed` - New COVID-19 vaccination doses administered (7-day smoothed). For countries that don't report vaccination data on a daily basis, we assume that vaccination changed equally on a daily basis over any periods in which no data was reported. This produces a complete series of daily figures, which is then averaged over a rolling 7-day window
#
# *   `total_vaccinations_per_hundred` - Total number of COVID-19 vaccination doses administered per 100 people in the total population
#
# *   `people_vaccinated_per_hundred` - Total number of people who received at least one vaccine dose per 100 people in the total population
#
# *   `people_fully_vaccinated_per_hundred` - Total number of people who received all doses prescribed by the initial vaccination protocol per 100 people in the total population
#
# *   `total_boosters_per_hundred` - Total number of COVID-19 vaccination booster doses administered per 100 people in the total population
#
# *   `new_vaccinations_smoothed_per_million` - New COVID-19 vaccination doses administered (7-day smoothed) per 1,000,000 people in the total population
#
# *   `new_people_vaccinated_smoothed` - Daily number of people receiving their first vaccine dose (7-day smoothed)
#
# *   `new_people_vaccinated_smoothed_per_hundred` - Daily number of people receiving their first vaccine dose (7-day smoothed) per 100 people in the total population

# %% [markdown]
# **Others**
#
# *   `iso_code` - ISO 3166-1 alpha-3 – three-letter country codes
#
# *   `continent` - Continent of the geographical location
#
# *   `location` - Geographical location
#
# *   `date` - Date of observation
#
# *   `population` - Population (latest available values).
#
# *   `population_density` - Number of people divided by land area, measured in square kilometers, most recent year available
#
# *   `median_age` - Median age of the population, UN projection for 2020
#
# *   `aged_65_older` - Share of the population that is 65 years and older, most recent year available
#
# *   `aged_70_older` - Share of the population that is 70 years and older in 2015
#
# *   `gdp_per_capita` - Gross domestic product at purchasing power parity (constant 2011 international dollars), most recent year available
#
# *   `extreme_poverty` - Share of the population living in extreme poverty, most recent year available since 2010
#
# *   `cardiovasc_death_rate` - Death rate from cardiovascular disease in 2017 (annual number of deaths per 100,000 people)
#
# *   `diabetes_prevalence` - Diabetes prevalence (% of population aged 20 to 79) in 2017
#
# *   `female_smokers` - Share of women who smoke, most recent year available
#
# *   `male_smokers` - Share of men who smoke, most recent year available
#
# *   `handwashing_facilities` - Share of the population with basic handwashing facilities on premises, most recent year available
#
# *   `hospital_beds_per_thousand` - Hospital beds per 1,000 people, most recent year available since 2010
#
# *   `life_expectancy` - Life expectancy at birth in 2019
#
# *   `human_development_index` - A composite index measuring average achievement in three basic dimensions of human development—a long and healthy life, knowledge and a decent standard of living.

# %% [markdown]
# ### **Importing COVID-19 data**

# %%
# import the necessary library (libs)
import pandas as pd 
import matplotlib.pyplot as plt 

# %matplotlib inline 

import warnings
warnings.filterwarnings('ignore')

# %%
# as the csv file is larger than 25MB, let's import it from the drive and not from github

from google.colab import drive
drive_mount = '/content/gdrive'
drive.mount(drive_mount)
# Out:
# Mounted at /content/gdrive

# %%
# import the necessary library (libs)
df = pd.read_csv('/content/gdrive/MyDrive/Notebooks /Data Science na Prática 3.0/2. Visualização de Dados/owid-covid-data.csv')

# %% [markdown]
# ### **Exploratory Data Analysis (EDA)**
#
#   Data exploration is the first step of data analysis used to explore and visualize data in order to get a better perspective on the data from the beginning or identify areas or patterns where you can delve deeper.
# Exploratory data analysis (EDA) is used by data scientists to analyze and investigate data sets and summarize their key characteristics, often using data visualization methods.

# %% [markdown]
# #### **Initial Exploratory Analysis**

# %%
# show first five inputs
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
# DataFrame Shape

print('Rows: {}'.format(df.shape[0]))
print('Columns: {}'.format(df.shape[1]))
# Out:
# Rows: 182249
# Columns: 67

# %%
# Checking DataFrame Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182249 entries, 0 to 182248
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    182249 non-null  object
#  1   continent                                   171593 non-null  object
#  2   location                                    182249 non-null  object
#  3   date                                        182249 non-null  object
#  4   total_cases                                 175377 non-null  float64
#  5   new_cases                                   175185 non-null  float64
#  6   new_cases_smoothed                          174016 non-null  float64
#  7   total_deaths                                157135 non-null  float64
#  8   new_deaths                                  157153 non-null  float64
# ...

# %% [markdown]
# When doing data analyses, it's important to check if there is null values. If there's it's important to know what are this data, how many and where it was collected from, in order to undestand why this data is null.

# %%
# Checking the amount of null values
print(df.isnull().sum())
# Out:
# iso_code                                        0
# continent                                   10656
# location                                        0
# date                                            0
# total_cases                                  6872
#                                             ...
# human_development_index                     35574
# excess_mortality_cumulative_absolute       175932
# excess_mortality_cumulative                175932
# excess_mortality                           175932
# excess_mortality_cumulative_per_million    175932
# Length: 67, dtype: int64

# %%
# Sorting Nulls in Descending Order
print(df.isnull().sum().sort_values(ascending=False))
# Out:
# weekly_icu_admissions_per_million          176359
# weekly_icu_admissions                      176359
# excess_mortality_cumulative_per_million    175932
# excess_mortality                           175932
# excess_mortality_cumulative                175932
#                                             ...
# total_cases                                  6872
# population                                   1128
# date                                            0
# location                                        0
# iso_code                                        0
# Length: 67, dtype: int64

# %%
# Checking null values
print((df.isnull().sum() / df.shape[0]).sort_values(ascending=False))
# Out:
# weekly_icu_admissions_per_million          0.967682
# weekly_icu_admissions                      0.967682
# excess_mortality_cumulative_per_million    0.965339
# excess_mortality                           0.965339
# excess_mortality_cumulative                0.965339
#                                              ...
# total_cases                                0.037707
# population                                 0.006189
# date                                       0.000000
# location                                   0.000000
# iso_code                                   0.000000
# Length: 67, dtype: float64

# %%
# Calculating the percentage of null values, sorting in descending order
print(((df.isnull().sum()/df.shape[0])*100).sort_values(ascending=False))
# Out:
# weekly_icu_admissions_per_million          96.768158
# weekly_icu_admissions                      96.768158
# excess_mortality_cumulative_per_million    96.533863
# excess_mortality                           96.533863
# excess_mortality_cumulative                96.533863
#                                              ...
# total_cases                                 3.770665
# population                                  0.618933
# date                                        0.000000
# location                                    0.000000
# iso_code                                    0.000000
# Length: 67, dtype: float64

# %%
# show only the first ten values
((df.isnull().sum()/df.shape[0])*100).sort_values(ascending=False)[0:10]
# Out:
# weekly_icu_admissions_per_million          96.768158
# weekly_icu_admissions                      96.768158
# excess_mortality_cumulative_per_million    96.533863
# excess_mortality                           96.533863
# excess_mortality_cumulative                96.533863
# excess_mortality_cumulative_absolute       96.533863
# weekly_hosp_admissions_per_million         93.520403
# weekly_hosp_admissions                     93.520403
# total_boosters                             87.809535
# total_boosters_per_hundred                 87.809535
# dtype: float64

# %% [markdown]
# As we saw when analyzing the type of variables, we verified that the `date`column is not in datetime format. So that we can exploit this variable to the fullest, let's transform it to the datetime format

# %%
# transforming the date column into datetime
df.date = pd.to_datetime(df.date)

# %% [markdown]
# After changing the format, let's check the most recent date in our dataset. With this information, let's check the leading country in cases at that time.

# %%
# checking the latest date from the dataset
df.date.max()
# Out:
# Timestamp('2022-04-28 00:00:00')

# %%
# Analyzing the total cases in descending order on the date 2020-06-15
df.loc[df.date == '2020-06-15'].sort_values(by="total_cases", ascending=False)
# Out:
#         iso_code      continent                      location       date  \
# 179277  OWID_WRL            NaN                         World 2020-06-15
# 71693   OWID_HIC            NaN                   High income 2020-06-15
# 173423  OWID_UMC            NaN           Upper middle income 2020-06-15
# 120794  OWID_NAM            NaN                 North America 2020-06-15
# 53084   OWID_EUR            NaN                        Europe 2020-06-15
# ...          ...            ...                           ...        ...
# 66528        GUM        Oceania                          Guam 2020-06-15
# 103961       MHL        Oceania              Marshall Islands 2020-06-15
# 122658       MNP        Oceania      Northern Mariana Islands 2020-06-15
# 133134       PRI  North America                   Puerto Rico 2020-06-15
# 172602       VIR  North America  United States Virgin Islands 2020-06-15
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %% [markdown]
# We can verify that the places in the world that were leaders in cases on June 15, 2020, were:
#
# * High Income - 4364796.0 total cases
# * Upper Middle Income - 2552889.0 total cases
# * North America - 2437576.0	total cases
# * Europe - 2189384.0 total cases

# %% [markdown]
# now, let's review the death cases

# %%
# Total numbers of deaths
df.loc[df.date == '2020-06-15'].sort_values(by="total_deaths", ascending=False)
# Out:
#         iso_code      continent                      location       date  \
# 179277  OWID_WRL            NaN                         World 2020-06-15
# 71693   OWID_HIC            NaN                   High income 2020-06-15
# 53084   OWID_EUR            NaN                        Europe 2020-06-15
# 120794  OWID_NAM            NaN                 North America 2020-06-15
# 53911   OWID_EUN            NaN                European Union 2020-06-15
# ...          ...            ...                           ...        ...
# 162728       TLS           Asia                         Timor 2020-06-15
# 168585       UGA         Africa                        Uganda 2020-06-15
# 172602       VIR  North America  United States Virgin Islands 2020-06-15
# 176292       VAT         Europe                       Vatican 2020-06-15
# 177893       VNM           Asia                       Vietnam 2020-06-15
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %% [markdown]
# Regarding deaths, the leading countries in total number of deaths were:
#
# * High Income - 304207.0 total deaths
# * Europe - 180673.0 total deaths
# * North America - 147311.0 total deaths

# %% [markdown]
# To improve the visualization, let's plot a bar graph.

# %%
# bar chart for total deaths on 2020-06-15
top_5_total_deaths = df.loc[df.date == '2020-06-15', ['location', 'total_deaths']].sort_values(by="total_deaths", ascending=False)[1:6]

fig, ax = plt.subplots(figsize=(15,10))

ax.bar('location', 'total_deaths', width=0.5, data=top_5_total_deaths)

plt.tight_layout()

# %% [markdown]
# #### How is the virus progressing?
#
# One of the biggest concerns of health organizations is the progression of the number of cases and deaths in the world.
#
# One of the best ways to visualize evolution over time is the line chart.
#
# So let's plot a line graph to demonstrate the evolution of deaths in the world.

# %%
# line graph for the progression of deaths in the world
df.loc[df.location == "World", "total_deaths"].reset_index(drop=True).plot(figsize=(10,8));

# %% [markdown]
# ###Exploratory Analysis for Brazil
#
# Now that we have an idea of what is happening in the world, let's focus on what is happening in Brazil.

# %%
# Create a copy of DataFrame with Brazil only
df_brasil = df.loc[df.location == "Brazil"].copy()

df_brasil.head()
# Out:
#       iso_code      continent location       date  total_cases  new_cases  \
# 22847      BRA  South America   Brazil 2020-02-26          1.0        1.0
# 22848      BRA  South America   Brazil 2020-02-27          1.0        0.0
# 22849      BRA  South America   Brazil 2020-02-28          1.0        0.0
# 22850      BRA  South America   Brazil 2020-02-29          2.0        1.0
# 22851      BRA  South America   Brazil 2020-03-01          2.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 22847                 NaN           NaN         NaN                  NaN  ...
# 22848                 NaN           NaN         NaN                  NaN  ...
# 22849                 NaN           NaN         NaN                  NaN  ...
# 22850                 NaN           NaN         NaN                  NaN  ...
# 22851                 NaN           NaN         NaN                  NaN  ...
#
# ...

# %%
# checking the latest date of Brazil from the dataset
df_brasil.date.max()
# Out:
# Timestamp('2022-04-28 00:00:00')

# %% [markdown]
# Above, we see that our dataset includes dates from **2019-12-31** to **2020-06-15**.

# %% [markdown]
# Let's check when the first death in Brazil were identified.

# %%
# Identify when the first death was recorded in Brazil
df_brasil.loc[df_brasil['new_deaths'] == 1.0].head(1)
# Out:
#       iso_code      continent location       date  total_cases  new_cases  \
# 22867      BRA  South America   Brazil 2020-03-17        321.0      121.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 22867              41.429           1.0         1.0                  NaN  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 22867            10.1          17.9                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 22867                         2.2            75.88                    0.765
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 22867                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 22867               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
print('The firt death was registeres on {}'.format(df_brasil.date.loc[22867]))
# Out:
# The firt death was registeres on 2020-03-17 00:00:00

# %% [markdown]
# Let's check when the first case in Brazil were identified.

# %%
# Identification of the first case registered in Brazil
df_brasil.loc[df_brasil['new_cases'] != 0.0].head(1)
# Out:
#       iso_code      continent location       date  total_cases  new_cases  \
# 22847      BRA  South America   Brazil 2020-02-26          1.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 22847                 NaN           NaN         NaN                  NaN  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 22847            10.1          17.9                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 22847                         2.2            75.88                    0.765
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 22847                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 22847               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
print('The first case was registeres on {}'.format(df_brasil.date.loc[22847]))
# Out:
# The first case was registeres on 2020-02-26 00:00:00

# %% [markdown]
# An interesting piece of information for us to investigate is how long it took from the first case to the first death.

# %%
# Identify how many days it took to register the first death, considering the first case of COVID-19 registered
# Calculating time from first case to first death
from datetime import date
delta = df_brasil.date.loc[22867] - df_brasil.date.loc[22847]
print('{} days passed between the first case and the first death in Brazil.'.format(delta.days))
# Out:
# 20 days passed between the first case and the first death in Brazil.

# %% [markdown]
# Finally, we will plot line graphs to compare the evolution of cases and
# deaths in Brazil.

# %%
# Plot line graphs on linear and logarithmic scales for total cases and total deaths.
# Plotar gráficos de linha em escalas linear e logarítmica para os casos totais e mortes totais.
x = list(range(793))
z = df_brasil['total_cases']
z2 = df_brasil['total_deaths']

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(9, 7))
ax1.set_title('Casos no Brasil')
ax1.set_xlabel('Dias')
ax1.set_ylabel('Casos')
ax1.plot(x, z)

ax2.set_title('Casos no Brasil (Escala logarítmica)')
ax2.set_xlabel('Dias')
ax2.set_ylabel('Casos')
ax2.set_yscale('log')
ax2.plot(x, z)

ax3.set_title('Mortes no Brasil')
ax3.set_xlabel('Dias')
ax3.set_ylabel('Mortes')
ax3.plot(x, z2)

ax4.set_title('Mortes no Brasil (Escala logarítmica')
ax4.set_xlabel('Dias')
ax4.set_ylabel('Mortes')
ax4.set_yscale('log')
ax4.plot(x, z2)
plt.tight_layout()

# %% [markdown]
# ## Conclusion
#
# An extremely important detail to note is that this data is measured daily, and this dataset will "quickly" go out of date.
#
# However, considering the context of the analyzed data, it is interesting to highlight:
#
# * The United States is skyrocketing in terms of cases and deaths.
# * The evolution of cases in Brazil is in an overwhelming growth.
# * Overall, cases and deaths are still growing.
#
# Many other analyzes can be taken from this dataset, but with this initial analysis we were able to extract a lot of information.
